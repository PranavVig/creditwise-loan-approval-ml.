# %% [markdown]
# # Explainability and Bias Checks
#
# This notebook evaluates model behavior across groups.

# %%
import json
import pandas as pd

with open('../reports/fairness_report.json', 'r', encoding='utf-8') as f:
    fairness = json.load(f)

pd.DataFrame(fairness['by_gender'])

# %%
pd.DataFrame(fairness['by_property_area'])

# %%
with open('../reports/best_model_metrics.json', 'r', encoding='utf-8') as f:
    best_metrics = json.load(f)
best_metrics
